# %%
# !pip install dtreeviz
# Out:
# Requirement already satisfied: dtreeviz in c:\users\justin thomas\anaconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: pytest in c:\users\justin thomas\anaconda3\lib\site-packages (from dtreeviz) (7.1.2)
# Requirement already satisfied: pandas in c:\users\justin thomas\anaconda3\lib\site-packages (from dtreeviz) (1.4.4)
# Requirement already satisfied: numpy in c:\users\justin thomas\anaconda3\lib\site-packages (from dtreeviz) (1.21.5)
# Requirement already satisfied: graphviz>=0.9 in c:\users\justin thomas\anaconda3\lib\site-packages (from dtreeviz) (0.20.1)
# Requirement already satisfied: matplotlib in c:\users\justin thomas\anaconda3\lib\site-packages (from dtreeviz) (3.5.2)
# Requirement already satisfied: scikit-learn in c:\users\justin thomas\anaconda3\lib\site-packages (from dtreeviz) (1.0.2)
# Requirement already satisfied: colour in c:\users\justin thomas\anaconda3\lib\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\justin thomas\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\justin thomas\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\justin thomas\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\justin thomas\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\justin thomas\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\justin thomas\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\justin thomas\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\justin thomas\anaconda3\lib\site-packages (from pandas->dtreeviz) (2022.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\justin thomas\anaconda3\lib\site-packages (from pytest->dtreeviz) (21.4.0)
# Requirement already satisfied: iniconfig in c:\users\justin thomas\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\justin thomas\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\justin thomas\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\justin thomas\anaconda3\lib\site-packages (from pytest->dtreeviz) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\justin thomas\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.4.0)
# Requirement already satisfied: colorama in c:\users\justin thomas\anaconda3\lib\site-packages (from pytest->dtreeviz) (0.4.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\justin thomas\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\justin thomas\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\justin thomas\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.9.1)
# Requirement already satisfied: six>=1.5 in c:\users\justin thomas\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'X[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %%
#1. Classification

# %%
viz = dtreeviz(clas, 
               X_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])
viz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25144\1431877341.py in <module>
# ----> 1 viz = dtreeviz(clas,
#       2                X_train,
#       3                y_train,
#       4                feature_names=iris.feature_names,
#       5                class_names=["setosa", "versicolor", "virginica"])
#
# NameError: name 'dtreeviz' is not defined

# %%
# REGRESSION
regr = tree.DecisionTreeRegressor(max_depth=1)
boston = load_boston()

X_train = boston.data
y_train = boston.target
regr.fit(X_train, y_train)

viz = dtreeviz(regr,
               X_train,
               y_train,
               target_name='price',
               feature_names=boston.feature_names,
               scale=2
              )
viz
# Out:
# C:\Users\Justin Thomas\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25144\2799178531.py in <module>
#       7 regr.fit(X_train, y_train)
#       8
# ----> 9 viz = dtreeviz(regr,
#      10                X_train,
#      11                y_train,
#
# NameError: name 'dtreeviz' is not defined

# %%
##3. Horizontal Decision Tree
viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               scale = 1.5,
               orientation='LR')
viz

# %%
##4. Show prediction path
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)

X = iris.data[np.random.randint(0, len(iris.data)),:]

viz = dtreeviz(clas, 
               X_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               X=X)
viz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25144\1789456424.py in <module>
#       9 X = iris.data[np.random.randint(0, len(iris.data)),:]
#      10
# ---> 11 viz = dtreeviz(clas,
#      12                X_train,
#      13                y_train,
#
# NameError: name 'dtreeviz' is not defined

# %%
X
# Out:
# array([5.6, 2.8, 4.9, 2. ])

# %%
### 5. Show node number
viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               histtype= 'barstacked',
               scale = 1.5,
               orientation='LR',
               show_node_labels=True)
viz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25144\2209805480.py in <module>
#       1 ### 5. Show node number
# ----> 2 viz = dtreeviz(clas,
#       3                X_train,
#       4                y_train,
#       5                target_name='price',
#
# NameError: name 'dtreeviz' is not defined

# %%
### 6. Without Any graphs
viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               histtype= 'barstacked',
               scale = 1.5,
               orientation='LR',
               fancy=False)
viz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25144\864231129.py in <module>
#       1 ### 6. Without Any graphs
# ----> 2 viz = dtreeviz(clas,
#       3                X_train,
#       4                y_train,
#       5                target_name='price',
#
# NameError: name 'dtreeviz' is not defined

# %%
###7. Show just prediction path, nothing else
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)

X = iris.data[np.random.randint(0, len(iris.data)),:]

viz = dtreeviz(clas, 
               X_train,
               y_train,
               target_name='price',
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"], 
               X=X,
               show_just_path=True)
viz

# %%
##8. Prediction Path in Plain english
print(explain_prediction_path(clas, X, feature_names=iris.feature_names, explanation_type="plain_english"))

# %%
### 9. Feature Importance
print(explain_prediction_path(clas, X, feature_names=iris.feature_names, explanation_type="sklearn_default"))

# %%
#### 10. Univariate Regression
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from dtreeviz.trees import *

df_cars = pd.read_csv("cars.csv")
X, y = df_cars[['WGT']], df_cars['MPG']

dt = DecisionTreeRegressor(max_depth=3, criterion="mae")
dt.fit(X, y)

fig = plt.figure()
ax = fig.gca()
rtreeviz_un

# %%
###11. 3-D Regression
df_cars = pd.read_csv("cars.csv")

df_cars

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.tree import DecisionTreeRegressor
from dtreeviz.trees import *


X = df_cars[['WGT','ENG']]
y = df_cars['MPG']

dt = DecisionTreeRegressor(max_depth=3, criterion="mae")
dt.fit(X, y)

figsize = (6,5)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111, projection='3d')

t = rtreeviz_bivar_3D(dt,
                      X, y,
                      feature_names=['Vehicle Weight', 'Horse Power'],
                      target_name='MPG',
                      fontsize=14,
                      elev=20,
                      azim=25,
                      dist=8.2,
                      show={'splits','title'},
                      ax=ax)
plt.show()
